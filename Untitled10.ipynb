# %% [markdown]
# <a href="https://colab.research.google.com/github/Peiyun1128/Y/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import matplotlib.pyplot as plt

# %%
 x=[1,2,3,4,5]

# %%
 plt.plot(x)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0,5,0.1)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
